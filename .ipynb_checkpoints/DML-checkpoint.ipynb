# %% [markdown]
# # NBA Championship Database - DML

# %%
#import all necessary packages and modules
import pandas as pd
import sqlite3

# %%
# standard imports for %sql magic
# %load_ext sql

# connect to %sql database connection, has been created in DDL notebook 
# %sql sqlite:///nba_db.db
# Out:
# 'Connected: None@nba_db.db'

# %% [markdown]
# ## Insert data into our main data table
# _The following insert statements were copied from sqlite3 commands to extract the data from our csv_

# %%
# %%sql
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','1','1','1','240','0','13','12','31','109');
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','2','0','1','240','0','8','15','37','104');
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','3','1','0','240','0','23','22','34','111');
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','4','0','0','240','0','14','18','31','102');
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','5','1','1','240','0','26','19','37','108');
# INSERT INTO NBAData VALUES('1980','Lakers','LAL','6','1','0','240','0','33','17','35','123');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','1','1','1','240','0','16','25','29','98');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','2','0','1','240','0','8','14','34','90');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','3','1','0','240','2','12','16','28','94');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','4','0','0','240','0','16','17','30','86');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','5','1','1','240','0','27','19','35','109');
# INSERT INTO NBAData VALUES('1981','Celtics','BOS','6','1','0','240','1','15','9','28','102');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','1','1','0','240','0','26','19','31','124');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','2','0','0','240','0','24','17','22','94');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','3','1','1','240','1','28','17','31','129');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','4','1','1','240','0','21','16','33','111');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','5','0','0','240','0','8','26','23','102');
# INSERT INTO NBAData VALUES('1982','Lakers','LAL','6','1','1','240','0','20','15','34','114');
# INSERT INTO NBAData VALUES('1983','Sixers','PHI','1','1','1','240','0','23','21','32','113');
# INSERT INTO NBAData VALUES('1983','Sixers','PHI','2','1','1','240','0','23','16','28','103');
# INSERT INTO NBAData VALUES('1983','Sixers','PHI','3','1','0','240','0','21','22','32','111');
# INSERT INTO NBAData VALUES('1983','Sixers','PHI','4','1','0','240','0','31','13','28','115');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','1','1','1','240','1','28','12','30','115');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','2','0','1','265','0','34','20','30','124');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','3','0','0','240','2','22','17','27','104');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','4','1','0','265','2','31','27','25','129');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','5','1','1','240','3','28','13','38','121');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','6','0','0','240','1','29','13','28','108');
# INSERT INTO NBAData VALUES('1984','Celtics','BOS','7','1','1','240','0','43','20','32','111');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','1','0','0','240','2','14','8','27','114');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','2','1','0','240','1','20','14','35','109');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','3','1','1','240','4','28','13','36','136');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','4','0','1','240','1','24','9','31','105');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','5','1','1','240','0','20','10','29','120');
# INSERT INTO NBAData VALUES('1985','Lakers','LAL','6','1','0','240','0','25','12','32','111');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','1','1','1','240','1','17','10','32','112');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','2','1','1','240','4','23','14','29','117');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','3','0','0','240','1','19','22','31','104');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','4','1','0','240','2','14','11','29','106');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','5','0','0','240','1','27','10','27','96');
# INSERT INTO NBAData VALUES('1986','Celtics','BOS','6','1','1','240','1','12','23','33','111');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','1','1','1','240','1','15','17','30','126');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','2','1','1','240','6','23','7','26','141');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','3','0','0','240','3','20','8','24','103');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','4','1','0','240','2','23','15','31','107');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','5','0','0','240','4','18','17','23','108');
# INSERT INTO NBAData VALUES('1987','Lakers','LAL','6','1','1','240','0','16','13','31','106');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','1','0','1','240','2','25','13','22','93');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','2','1','1','240','3','35','8','35','108');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','3','1','0','240','1','24','5','33','99');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','4','0','0','240','0','28','8','26','86');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','5','0','0','240','1','19','15','16','94');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','6','1','1','240','0','35','13','28','103');
# INSERT INTO NBAData VALUES('1988','Lakers','LAL','7','1','1','240','3','19','10','31','108');
# INSERT INTO NBAData VALUES('1989','Pistons','DET','1','1','1','240','1','16','9','36','109');
# INSERT INTO NBAData VALUES('1989','Pistons','DET','2','1','1','240','1','19','13','22','108');
# INSERT INTO NBAData VALUES('1989','Pistons','DET','3','1','0','240','1','27','14','30','114');
# INSERT INTO NBAData VALUES('1989','Pistons','DET','4','1','0','240','2','35','9','27','105');
# INSERT INTO NBAData VALUES('1990','Pistons','DET','1','1','1','240','3','34','19','35','105');
# INSERT INTO NBAData VALUES('1990','Pistons','DET','2','0','1','265','8','15','15','29','105');
# INSERT INTO NBAData VALUES('1990','Pistons','DET','3','1','0','240','3','32','10','26','121');
# INSERT INTO NBAData VALUES('1990','Pistons','DET','4','1','0','240','7','21','12','27','112');
# INSERT INTO NBAData VALUES('1990','Pistons','DET','5','1','0','240','4','14','16','28','92');
# INSERT INTO NBAData VALUES('1991','Bulls','CHI','1','0','1','240','1','14','9','30','91');
# INSERT INTO NBAData VALUES('1991','Bulls','CHI','2','1','1','240','0','7','11','25','107');
# INSERT INTO NBAData VALUES('1991','Bulls','CHI','3','1','0','265','1','21','16','30','104');
# INSERT INTO NBAData VALUES('1991','Bulls','CHI','4','1','0','240','1','12','9','29','97');
# INSERT INTO NBAData VALUES('1991','Bulls','CHI','5','1','0','240','2','22','10','27','108');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','1','1','1','240','7','15','16','28','122');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','2','0','1','265','5','17','10','31','104');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','3','1','0','240','1','19','9','33','94');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','4','0','0','240','4','14','7','26','88');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','5','1','0','240','2','37','10','24','119');
# INSERT INTO NBAData VALUES('1992','Bulls','CHI','6','1','1','240','6','15','9','22','97');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','1','1','0','240','3','11','10','31','100');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','2','1','0','240','3','18','17','26','111');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','3','0','1','315','5','6','27','32','121');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','4','1','1','240','3','20','12','30','111');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','5','0','1','240','8','16','8','27','98');
# INSERT INTO NBAData VALUES('1993','Bulls','CHI','6','1','0','240','10','11','12','27','99');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','1','1','1','240','4','19','12','37','85');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','2','0','1','240','6','13','17','21','83');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','3','1','0','240','6','27','14','33','93');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','4','0','0','240','6','14','7','26','82');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','5','0','0','240','6','12','15','27','84');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','6','1','1','240','5','17','6','32','86');
# INSERT INTO NBAData VALUES('1994','Rockets','HOU','7','1','1','240','4','18','3','30','90');
# INSERT INTO NBAData VALUES('1995','Rockets','HOU','1','1','0','265','14','18','9','32','120');
# INSERT INTO NBAData VALUES('1995','Rockets','HOU','2','1','0','240','5','34','9','29','117');
# INSERT INTO NBAData VALUES('1995','Rockets','HOU','3','1','1','240','7','21','11','35','106');
# INSERT INTO NBAData VALUES('1995','Rockets','HOU','4','1','1','240','11','22','15','33','113');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','1','1','1','240','7','26','17','23','107');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','2','1','1','240','4','28','20','25','92');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','3','1','0','240','7','25','10','23','108');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','4','0','0','240','6','16','15','21','86');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','5','0','0','240','3','17','15','25','78');
# INSERT INTO NBAData VALUES('1996','Bulls','CHI','6','1','0','240','9','16','24','27','87');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','1','1','1','240','6','10','10','26','84');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','2','1','1','240','6','27','11','30','97');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','3','0','0','240','12','15','8','27','93');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','4','0','0','240','4','5','10','28','73');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','5','1','0','240','6','20','10','32','90');
# INSERT INTO NBAData VALUES('1997','Bulls','CHI','6','1','1','240','5','23','15','35','90');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','1','0','0','265','3','14','9','32','85');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','2','1','0','240','3','22','18','18','93');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','3','1','1','240','4','18','11','39','96');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','4','1','1','240','5','27','17','27','86');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','5','0','1','240','7','16','13','20','81');
# INSERT INTO NBAData VALUES('1998','Bulls','CHI','6','1','0','240','4','15','5','17','87');
# INSERT INTO NBAData VALUES('1999','Spurs','SAS','1','1','1','240','6','19','4','33','89');
# INSERT INTO NBAData VALUES('1999','Spurs','SAS','2','1','1','240','2','24','5','36','80');
# INSERT INTO NBAData VALUES('1999','Spurs','SAS','3','0','0','240','5','18','10','26','81');
# INSERT INTO NBAData VALUES('1999','Spurs','SAS','4','1','0','240','3','23','14','35','96');
# INSERT INTO NBAData VALUES('1999','Spurs','SAS','5','1','0','240','5','19','9','31','78');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','1','1','1','240','3','11','14','34','104');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','2','1','1','240','7','32','11','36','111');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','3','0','0','240','7','8','8','25','91');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','4','1','0','265','4','20','14','28','120');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','5','0','0','240','4','11','13','21','87');
# INSERT INTO NBAData VALUES('2000','Lakers','LAL','6','1','1','240','10','20','13','31','116');
# INSERT INTO NBAData VALUES('2001','Lakers','LAL','1','0','1','265','6','15','16','28','101');
# INSERT INTO NBAData VALUES('2001','Lakers','LAL','2','1','1','240','4','18','15','37','98');
# INSERT INTO NBAData VALUES('2001','Lakers','LAL','3','1','0','240','4','22','10','30','96');
# INSERT INTO NBAData VALUES('2001','Lakers','LAL','4','1','0','240','10','18','12','31','100');
# INSERT INTO NBAData VALUES('2001','Lakers','LAL','5','1','0','240','12','32','14','33','108');
# INSERT INTO NBAData VALUES('2002','Lakers','LAL','1','1','1','240','1','32','17','33','99');
# INSERT INTO NBAData VALUES('2002','Lakers','LAL','2','1','1','240','9','19','12','35','106');
# INSERT INTO NBAData VALUES('2002','Lakers','LAL','3','1','0','240','8','24','7','33','106');
# INSERT INTO NBAData VALUES('2002','Lakers','LAL','4','1','0','240','11','28','7','32','113');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','1','1','1','240','4','19','10','37','101');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','2','0','1','240','5','14','14','29','85');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','3','1','0','240','5','23','9','29','84');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','4','0','0','240','4','20','22','31','76');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','5','1','0','240','3','24','8','31','93');
# INSERT INTO NBAData VALUES('2003','Spurs','SAS','6','1','1','240','3','17','11','44','88');
# INSERT INTO NBAData VALUES('2004','Pistons','DET','1','1','0','240','6','21','9','27','87');
# INSERT INTO NBAData VALUES('2004','Pistons','DET','2','0','0','265','6','21','19','27','91');
# INSERT INTO NBAData VALUES('2004','Pistons','DET','3','1','1','240','5','21','15','36','88');
# INSERT INTO NBAData VALUES('2004','Pistons','DET','4','1','1','240','2','28','9','36','88');
# INSERT INTO NBAData VALUES('2004','Pistons','DET','5','1','1','240','2','28','20','30','100');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','1','1','1','240','4','12','15','34','84');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','2','1','1','240','11','28','9','27','97');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','3','0','0','240','8','13','10','27','79');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','4','0','0','240','5','14','12','32','71');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','5','1','0','265','8','12','19','26','96');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','6','0','1','240','8','16','13','30','86');
# INSERT INTO NBAData VALUES('2005','Spurs','SAS','7','1','1','240','7','16','8','30','81');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','1','0','0','240','5','7','12','33','80');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','2','0','0','240','7','20','8','24','85');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','3','1','1','240','4','20','16','33','98');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','4','1','1','240','7','23','6','42','98');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','5','1','1','265','7','32','7','26','101');
# INSERT INTO NBAData VALUES('2006','Heat','MIA','6','1','0','240','2','23','14','42','95');
# INSERT INTO NBAData VALUES('2007','Spurs','SAS','1','1','1','240','6','11','13','30','85');
# INSERT INTO NBAData VALUES('2007','Spurs','SAS','2','1','1','240','8','21','12','34','103');
# INSERT INTO NBAData VALUES('2007','Spurs','SAS','3','1','0','240','10','9','7','34','75');
# INSERT INTO NBAData VALUES('2007','Spurs','SAS','4','1','0','240','5','20','11','34','83');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','1','1','1','240','6','28','10','36','98');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','2','1','1','240','9','27','10','27','108');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','3','0','0','240','8','15','14','31','81');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','4','1','0','240','8','23','6','34','97');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','5','0','0','240','8','24','11','26','98');
# INSERT INTO NBAData VALUES('2008','Celtics','BOS','6','1','1','240','13','32','14','34','131');
# INSERT INTO NBAData VALUES('2009','Lakers','LAL','1','1','1','240','3','15','15','40','100');
# INSERT INTO NBAData VALUES('2009','Lakers','LAL','2','1','1','265','5','24','4','31','101');
# INSERT INTO NBAData VALUES('2009','Lakers','LAL','3','0','0','240','8','16','11','16','104');
# INSERT INTO NBAData VALUES('2009','Lakers','LAL','4','1','0','265','8','15','10','29','99');
# INSERT INTO NBAData VALUES('2009','Lakers','LAL','5','1','0','240','8','21','13','34','99');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','1','1','1','240','4','24','12','30','102');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','2','0','1','240','5','31','10','29','94');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','3','1','0','240','2','21','11','32','91');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','4','0','0','240','7','18','8','26','89');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','5','0','0','240','7','17','16','18','86');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','6','1','1','240','6','17','12','40','89');
# INSERT INTO NBAData VALUES('2010','Lakers','LAL','7','1','1','240','4','25','23','30','83');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','1','0','0','240','9','25','6','30','84');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','2','1','0','240','6','17','11','30','95');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','3','0','1','240','8','22','12','30','86');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','4','1','1','240','4','24','12','29','86');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','5','1','1','240','13','21','4','22','112');
# INSERT INTO NBAData VALUES('2011','Mavericks','DAL','6','1','0','240','11','12','10','30','105');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','1','0','0','240','8','14','7','28','94');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','2','1','0','240','6','22','11','29','100');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','3','1','1','240','4','31','14','31','91');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','4','1','1','240','10','18','9','31','104');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','5','1','1','240','14','27','8','33','121');
# INSERT INTO NBAData VALUES('2012','Heat','MIA','1','0','1','240','8','12','9','37','88');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','2','1','1','240','10','11','9','27','103');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','3','0','0','240','8','7','9','27','77');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','4','1','0','240','4','15','7','34','109');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','5','0','0','240','11','19','12','22','104');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','6','1','1','265','11','16','12','30','103');
# INSERT INTO NBAData VALUES('2013','Heat','MIA','7','1','1','240','12','11','11','32','95');
# INSERT INTO NBAData VALUES('2014','Spurs','SAS','1','1','1','240','13','17','5','34','110');
# INSERT INTO NBAData VALUES('2014','Spurs','SAS','2','0','1','240','12','12','11','26','96');
# INSERT INTO NBAData VALUES('2014','Spurs','SAS','3','1','0','240','9','26','5','24','111');
# INSERT INTO NBAData VALUES('2014','Spurs','SAS','4','1','0','240','9','18','12','32','107');
# INSERT INTO NBAData VALUES('2014','Spurs','SAS','5','1','1','240','12','18','6','34','104');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','1','1','1','265','10','20','11','37','108');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','2','0','1','265','8','19','10','35','93');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','3','0','0','240','12','7','18','28','91');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','4','1','0','240','12','19','6','38','103');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','5','1','1','240','12','20','11','32','104');
# INSERT INTO NBAData VALUES('2015','Warriors','GSW','6','1','0','240','13','18','7','32','105');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','1','0','0','240','7','18','15','32','89');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','2','0','0','240','5','16','9','25','77');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','3','1','1','240','12','12','17','35','120');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','4','0','1','240','6','15','16','24','97');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','5','1','0','240','10','14','8','33','112');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','6','1','1','240','10','25','8','37','115');
# INSERT INTO NBAData VALUES('2016','Cavaliers','CLE','7','1','0','240','6','21','9','39','93');
# INSERT INTO NBAData VALUES('2017','Warriors','GSW','1','1','1','240','12','11','14','36','113');
# INSERT INTO NBAData VALUES('2017','Warriors','GSW','2','1','1','240','18','22','10','43','132');
# INSERT INTO NBAData VALUES('2017','Warriors','GSW','3','1','0','240','16','22','8','36','118');
# INSERT INTO NBAData VALUES('2017','Warriors','GSW','4','0','0','240','11','27','16','24','116');
# INSERT INTO NBAData VALUES('2017','Warriors','GSW','5','1','1','240','14','23','13','29','129');
# Out:
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# ...

# %% [markdown]
# ## Migration
# * The following code was used to grab data from a web based csv, which we will grab data from to import and query into our database without downloading the actual file. Once retrieved, the data in formated into a datafram and transferred our sqlite3 database using the .to_sql command

# %%
#connect to web based csv file and create dataframe
players = pd.read_csv('https://query.data.world/s/ITKVBzG71Zh6xB8e4tltf0roHnOaQJ')
players_df = pd.DataFrame(players)
players_df.to_sql('PlayerData', sqlite3.connect('nba_db.db'),index=False)
# Out:
# C:\Users\engu\Anaconda3\lib\site-packages\pandas\core\generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
# %%sql
# SELECT * from PlayerData limit 10;
# Out:
# Done.
# [(1978, 'NOJ', 'Truck Robinson', 26, 82, 3638, 15.7, 0.48100000000000004, None, 0.34, 8.0, 25.8, 17.0, 6.8, 0.9, 1.1, 13.5, 23.3, None, 1.5, 5.0, 6.5, 0.086, None, -1.4, 0.2, -1.2, 0.7, 0.02, 0.066, 20.2, 'robintr01', -1.61, 19780, 82, 0.0, 0.505, 331339, 0.512, -1.73, -1.12, -0.16, -0.37, 2.0, -1.21, '92.00%', -1.12, -1.28, -0.13, -1.3, 2.0, -1.2, 0.6, -1.0, 0.2, -0.7, -0.3, 1.0, -0.8, -0.7, -1.9, 1.1, -0.7, 0.3, -1.5, 1.3, -1.4, 0.2, 0.1, 1.5, 0.1, 0.4, -1.6, 0.9, 44.4, 42.3, -1.3, -1.2, 0.6, 0.6, -1.5, -1.4, 0.2, 0.2, 0.1, 0.1, 0.4, 0.4, '$3,900,000 ', '$3,900,000 ', 3.2, 0.7, 0.6, 1.6, '$8,800,000 ', 0.4, '$2,900,000 ', 1.6, 0.6, 1.1, 1.1, 3.6, 4.0, 26.33, 3.0, 79.0, 225.0, 4.0, 26.0),
# ...

# %%
## Delete data from the tables in the event that the queries are ran again and to avoid duplicate data

# %%
# %%sql
# DELETE from Team;
# DELETE from Game;
# DELETE from Stats;
# DELETE from Season;
# DELETE from Player
# Out:
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ## Insert data into the tables we have created from both csv files(imported and url)

# %%
# %%sql
# INSERT INTO Team(TeamID, TeamName)
# SELECT DISTINCT TeamID, TeamName
# From NBAData;
#
# INSERT INTO Game(GameNumber, TeamId, Minutes, Year)
# SELECT DISTINCT GameID, Team.TeamID, Minutes, Year
# FROM Team JOIN NBAData ON (NBAData.TeamID = Team.TeamID);
#
#
# INSERT INTO Stats(Points, TeamID, ThreePts, FreeThrow, OffenseRebound, DefenseRebound, Home, Win)
# SELECT DISTINCT Points, Team.TeamID, ThreePts, FreeThrow, OffensiveRebound, DefensiveRebound, Home, Win
# From Team JOIN NBAData ON (NBAData.TeamID = Team.TeamID);
#
# INSERT INTO Season(Year, TeamID)
# SELECT DISTINCT Year, Team.TeamID
# FROM NBAData Join Team ON (Team.TeamID = NBAData.TeamID);
#
# INSERT INTO Player(PlayerName, TeamID, SeasonID, Age)
# SELECT DISTINCT Player, Team.TeamID, Season.SeasonID, Age
# FROM PlayerData JOIN Team ON (Team.TeamID = PlayerData.Tm)
#             JOIN Season ON (Season.Year = PlayerData.year);
# Out:
# 11 rows affected.
# 215 rows affected.
# 216 rows affected.
# 38 rows affected.
# 6526 rows affected.
# []

# %%
# %%sql
# SELECT DISTINCT Player, Season.TeamID, Year
# from Player JOIN Season ON (Player.TeamID=Season.TeamID)
# where Season.Year = 2000
# ;
# Out:
# (sqlite3.OperationalError) no such column: Player [SQL: 'SELECT DISTINCT Player, Season.TeamID, Year\nfrom Player JOIN Season ON (Player.TeamID=Season.TeamID)\nwhere Season.Year = 2000\n;']

# %% [markdown]
# **Let's find out the average age of players on the winning team in 1990**

# %%
# %%sql
# SELECT AVG(AGE),TeamName, Season.Year
# from Player JOIN Team ON (Player.TeamID=Team.TeamID)
#             JOIN SEASON ON (Player.SeasonID=Season.SeasonID);
# Out:
# Done.
# [(26.920931657983452, 'Warriors', 2016)]

# %% [markdown]
# **Let's find out how many times the Celtics has won a championship since 1980**

# %%
# %%sql
# SELECT COUNT(DISTINCT YEAR), TeamName
# From Season JOIN Team ON (Team.TeamID=Season.TeamID)
# Where Team.TeamID = 'BOS';
# Out:
# Done.
# [(4, 'Celtics')]

# %% [markdown]
# **....and who has won the championships the most since 1980..**

# %%
# %%sql
# SELECT Count(Year), TeamName
# From Season JOIN Team ON (Team.TeamID=Season.TeamID)
# Group by TeamName
# Order by Count(year) desc;
# Out:
# Done.
# [(10, 'Lakers'),
#  (6, 'Bulls'),
#  (5, 'Spurs'),
#  (4, 'Celtics'),
#  (3, 'Heat'),
#  (3, 'Pistons'),
#  (2, 'Rockets'),
#  (2, 'Warriors'),
#  (1, 'Cavaliers'),
#  (1, 'Mavericks'),
#  (1, 'Sixers')]

# %% [markdown]
# **stats about the rockets championship games **

# %%
# %%sql
# SELECT TeamName, Points AS [Points Per Game], FreeThrow AS [Free Throws Per Game], (OffenseRebound+DefenseRebound) AS [TotalRebounds]
# from Stats JOIN Team ON (Team.TeamID=Stats.TeamID)
# Where Team.TeamID = "HOU";
# Out:
# Done.
# [('Rockets', 85, 19, 49),
#  ('Rockets', 83, 13, 38),
#  ('Rockets', 93, 27, 47),
#  ('Rockets', 82, 14, 33),
#  ('Rockets', 84, 12, 42),
#  ('Rockets', 86, 17, 38),
#  ('Rockets', 90, 18, 33),
#  ('Rockets', 120, 18, 41),
#  ('Rockets', 117, 34, 38),
#  ('Rockets', 106, 21, 46),
#  ('Rockets', 113, 22, 48)]
