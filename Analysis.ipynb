# %% [markdown]
# # NBA Championship Analysis

# %%
#import all necessary packages and modules
import pandas as pd
import sqlite3

# %%
# standard imports for %sql magic
# %load_ext sql

# initialize a %sql database connection
# %sql sqlite:///nba_db.db
# Out:
# 'Connected: None@nba_db.db'

# %% [markdown]
# ## To test out the Migrated Data, we created a few select queries

# %% [markdown]
# **Let's find out all players who played on the winning team of 2000**

# %%
# %%sql
# SELECT DISTINCT PlayerName, Season.TeamID, Year
# from Player JOIN Season ON (Player.TeamID=Season.TeamID)
# where Season.Year = 2000
# ;
# Out:
# Done.
# [('0', 'LAL', 2000),
#  ('A.C. Green', 'LAL', 2000),
#  ('Aaron McKie', 'LAL', 2000),
#  ('Adam Morrison', 'LAL', 2000),
#  ('Adrian Branch', 'LAL', 2000),
#  ('Alan Hardy', 'LAL', 2000),
#  ('Alex Blackwell', 'LAL', 2000),
#  ('Andrew Bynum', 'LAL', 2000),
#  ('Andrew Goudelock', 'LAL', 2000),
#  ('Antawn Jamison', 'LAL', 2000),
#  ('Anthony Brown', 'LAL', 2000),
#  ('Anthony Miller', 'LAL', 2000),
#  ('Anthony Peeler', 'LAL', 2000),
#  ('Antonio Harvey', 'LAL', 2000),
#  ('Benoit Benjamin', 'LAL', 2000),
#  ('Billy Ray Bates', 'LAL', 2000),
#  ('Billy Thompson', 'LAL', 2000),
#  ('Bob McAdoo', 'LAL', 2000),
#  ('Brad Holland', 'LAL', 2000),
#  ('Brandon Bass', 'LAL', 2000),
#  ('Brian Cook', 'LAL', 2000),
#  ('Brian Grant', 'LAL', 2000),
#  ('Brian Shaw', 'LAL', 2000),
#  ('Bryon Russell', 'LAL', 2000),
#  ('Butch Carter', 'LAL', 2000),
#  ('Butch Lee', 'LAL', 2000),
#  ('Byron Scott', 'LAL', 2000),
#  ('Calvin Garrett', 'LAL', 2000),
#  ('Carlos Boozer', 'LAL', 2000),
#  ('Caron Butler', 'LAL', 2000),
#  ('Cedric Ceballos', 'LAL', 2000),
#  ('Chris Duhon', 'LAL', 2000),
#  ('Chris Kaman', 'LAL', 2000),
#  ('Chris Mihm', 'LAL', 2000),
#  ('Christian Eyenga', 'LAL', 2000),
#  ('Chuck Nevitt', 'LAL', 2000),
#  ('Chucky Atkins', 'LAL', 2000),
#  ('Chucky Brown', 'LAL', 2000),
#  ('Clay Johnson', 'LAL', 2000),
#  ('Cliff Robinson', 'LAL', 2000),
#  ('Coby Karl', 'LAL', 2000),
#  ('Corie Blount', 'LAL', 2000),
#  ("D'Angelo Russell", 'LAL', 2000),
#  ('Danny Schayes', 'LAL', 2000),
#  ('Darius Johnson-Odom', 'LAL', 2000),
#  ('Darius Morris', 'LAL', 2000),
#  ('David Rivers', 'LAL', 2000),
#  ('Demetrius Calip', 'LAL', 2000),
#  ('Dennis Rodman', 'LAL', 2000),
#  ('Derek Fisher', 'LAL', 2000),
#  ('Derek Harper', 'LAL', 2000),
#  ('Derek Strong', 'LAL', 2000),
#  ('Derrick Caracter', 'LAL', 2000),
#  ('Devean George', 'LAL', 2000),
#  ('Devin Ebanks', 'LAL', 2000),
#  ('Devin Green', 'LAL', 2000),
#  ('Didier Ilunga-Mbenga', 'LAL', 2000),
#  ('Don Ford', 'LAL', 2000),
#  ('Doug Christie', 'LAL', 2000),
#  ('Duane Cooper', 'LAL', 2000),
#  ('Dwight Buycks', 'LAL', 2000),
#  ('Dwight Howard', 'LAL', 2000),
#  ('Dwight Jones', 'LAL', 2000),
#  ('Earl Clark', 'LAL', 2000),
#  ('Earl Jones', 'LAL', 2000),
#  ('Ed Davis', 'LAL', 2000),
#  ('Eddie Jones', 'LAL', 2000),
#  ('Eddie Jordan', 'LAL', 2000),
#  ('Elden Campbell', 'LAL', 2000),
#  ('Elias Harris', 'LAL', 2000),
#  ('Frank Brickowski', 'LAL', 2000),
#  ('Frankie King', 'LAL', 2000),
#  ('Fred Roberts', 'LAL', 2000),
#  ('Gary Payton', 'LAL', 2000),
#  ('George Lynch', 'LAL', 2000),
#  ('George McCloud', 'LAL', 2000),
#  ('Glen Rice', 'LAL', 2000),
#  ('Greg Foster', 'LAL', 2000),
#  ('Horace Grant', 'LAL', 2000),
#  ('Ime Udoka', 'LAL', 2000),
#  ('Ira Newble', 'LAL', 2000),
#  ('Irving Thomas', 'LAL', 2000),
#  ('Isaiah Rider', 'LAL', 2000),
#  ('J.R. Reid', 'LAL', 2000),
#  ('Jabari Brown', 'LAL', 2000),
#  ('Jack Haley', 'LAL', 2000),
#  ('Jamaal Wilkes', 'LAL', 2000),
#  ('Jamal Sampson', 'LAL', 2000),
#  ('James Edwards', 'LAL', 2000),
#  ('James Worthy', 'LAL', 2000),
#  ('Jannero Pargo', 'LAL', 2000),
#  ('Jason Kapono', 'LAL', 2000),
#  ('Javaris Crittenton', 'LAL', 2000),
#  ('Jawann Oldham', 'LAL', 2000),
#  ('Jay Vincent', 'LAL', 2000),
#  ('Jeff Lamp', 'LAL', 2000),
#  ('Jelani McCoy', 'LAL', 2000),
#  ('Jeremy Lin', 'LAL', 2000),
#  ('Jerome Henderson', 'LAL', 2000),
#  ('Jerome Kersey', 'LAL', 2000),
#  ('Jim Brewer', 'LAL', 2000),
#  ('Jim Chones', 'LAL', 2000),
#  ('Jim Jackson', 'LAL', 2000),
#  ('Jodie Meeks', 'LAL', 2000),
#  ('Joe Cooper', 'LAL', 2000),
#  ('Joe Crispin', 'LAL', 2000),
#  ('Joe Kleine', 'LAL', 2000),
#  ('Joe Smith', 'LAL', 2000),
#  ('John Celestand', 'LAL', 2000),
#  ('John Salley', 'LAL', 2000),
#  ('Jon Barry', 'LAL', 2000),
#  ('Jordan Clarkson', 'LAL', 2000),
#  ('Jordan Farmar', 'LAL', 2000),
#  ('Jordan Hill', 'LAL', 2000),
#  ('Josh McRoberts', 'LAL', 2000),
#  ('Josh Powell', 'LAL', 2000),
#  ('Julius Randle', 'LAL', 2000),
#  ('Jumaine Jones', 'LAL', 2000),
#  ('Kareem Abdul-Jabbar', 'LAL', 2000),
#  ('Kareem Rush', 'LAL', 2000),
#  ('Karl Malone', 'LAL', 2000),
#  ('Keith Owens', 'LAL', 2000),
#  ('Kendall Marshall', 'LAL', 2000),
#  ('Kenny Carr', 'LAL', 2000),
#  ('Kent Bazemore', 'LAL', 2000),
#  ('Kevin McKenna', 'LAL', 2000),
#  ('Kobe Bryant', 'LAL', 2000),
#  ('Kurt Rambis', 'LAL', 2000),
#  ('Kwame Brown', 'LAL', 2000),
#  ('Lamar Odom', 'LAL', 2000),
#  ('Laron Profit', 'LAL', 2000),
#  ('Larry Drew', 'LAL', 2000),
#  ('Larry Krystkowiak', 'LAL', 2000),
#  ('Larry Nance Jr.', 'LAL', 2000),
#  ('Larry Spriggs', 'LAL', 2000),
#  ('Lester Conner', 'LAL', 2000),
#  ('Lindsey Hunter', 'LAL', 2000),
#  ('Lloyd Daniels', 'LAL', 2000),
#  ('Lou Williams', 'LAL', 2000),
#  ('Luke Walton', 'LAL', 2000),
#  ('Magic Johnson', 'LAL', 2000),
#  ('Manny Harris', 'LAL', 2000),
#  ('MarShon Brooks', 'LAL', 2000),
#  ('Marcelo Huertas', 'LAL', 2000),
#  ('Mario Bennett', 'LAL', 2000),
#  ('Mark Landsberger', 'LAL', 2000),
#  ('Mark Madsen', 'LAL', 2000),
#  ('Mark McNamara', 'LAL', 2000),
#  ('Marty Byrnes', 'LAL', 2000),
#  ('Matt Barnes', 'LAL', 2000),
#  ('Maurice Carter', 'LAL', 2000),
#  ('Maurice Evans', 'LAL', 2000),
#  ('Maurice Lucas', 'LAL', 2000),
#  ('Mel McCants', 'LAL', 2000),
#  ('Metta World Peace', 'LAL', 2000),
#  ('Michael Cooper', 'LAL', 2000),
#  ('Mike Higgins', 'LAL', 2000),
#  ('Mike McGee', 'LAL', 2000),
#  ('Mike Penberthy', 'LAL', 2000),
#  ('Mike Smrek', 'LAL', 2000),
#  ('Milt Wagner', 'LAL', 2000),
#  ('Mitch Kupchak', 'LAL', 2000),
#  ('Mitch Richmond', 'LAL', 2000),
#  ('Mychal Thompson', 'LAL', 2000),
#  ('Myles Patrick', 'LAL', 2000),
#  ('Nick Van Exel', 'LAL', 2000),
#  ('Nick Young', 'LAL', 2000),
#  ('Norm Nixon', 'LAL', 2000),
#  ('Ollie Mack', 'LAL', 2000),
#  ('Orlando Woolridge', 'LAL', 2000),
#  ('Pau Gasol', 'LAL', 2000),
#  ('Petur Gudmundsson', 'LAL', 2000),
#  ('Ramon Sessions', 'LAL', 2000),
#  ('Randolph Keys', 'LAL', 2000),
#  ('Ray Tolbert', 'LAL', 2000),
#  ('Reggie Jordan', 'LAL', 2000),
#  ('Rick Fox', 'LAL', 2000),
#  ('Robert Horry', 'LAL', 2000),
#  ('Robert Sacre', 'LAL', 2000),
#  ('Ron Boone', 'LAL', 2000),
#  ('Ron Harper', 'LAL', 2000),
#  ('Ronnie Lester', 'LAL', 2000),
#  ('Ronnie Price', 'LAL', 2000),
#  ('Ronny Turiaf', 'LAL', 2000),
#  ('Rory Sparrow', 'LAL', 2000),
#  ('Roy Hibbert', 'LAL', 2000),
#  ('Ruben Patterson', 'LAL', 2000),
#  ('Rumeal Robinson', 'LAL', 2000),
#  ('Ryan Kelly', 'LAL', 2000),
#  ('Sam Bowie', 'LAL', 2000),
#  ('Sam Jacobson', 'LAL', 2000),
#  ('Sam Perkins', 'LAL', 2000),
#  ('Samaki Walker', 'LAL', 2000),
#  ('Sasha Vujacic', 'LAL', 2000),
#  ('Sean Rooks', 'LAL', 2000),
#  ('Sedale Threatt', 'LAL', 2000),
#  ('Shammond Williams', 'LAL', 2000),
#  ('Shannon Brown', 'LAL', 2000),
#  ("Shaquille O'Neal", 'LAL', 2000),
#  ('Shawne Williams', 'LAL', 2000),
#  ('Shea Seals', 'LAL', 2000),
#  ('Smush Parker', 'LAL', 2000),
#  ('Soumaila Samake', 'LAL', 2000),
#  ('Spencer Haywood', 'LAL', 2000),
#  ('Stanislav Medvedenko', 'LAL', 2000),
#  ('Steve Blake', 'LAL', 2000),
#  ('Steve Bucknall', 'LAL', 2000),
#  ('Steve Mix', 'LAL', 2000),
#  ('Steve Nash', 'LAL', 2000),
#  ('Sun Yue', 'LAL', 2000),
#  ('Swen Nater', 'LAL', 2000),
#  ('Tarik Black', 'LAL', 2000),
#  ('Terry Teagle', 'LAL', 2000),
#  ('Theo Ratliff', 'LAL', 2000),
#  ('Tierre Brown', 'LAL', 2000),
#  ('Tony Bobbitt', 'LAL', 2000),
#  ('Tony Brown', 'LAL', 2000),
#  ('Tony Campbell', 'LAL', 2000),
#  ('Tony Jackson', 'LAL', 2000),
#  ('Tony Smith', 'LAL', 2000),
#  ('Tracy Murray', 'LAL', 2000),
#  ('Travis Knight', 'LAL', 2000),
#  ('Trevor Ariza', 'LAL', 2000),
#  ('Trevor Wilson', 'LAL', 2000),
#  ('Trey Johnson', 'LAL', 2000),
#  ('Troy Murphy', 'LAL', 2000),
#  ('Tyronn Lue', 'LAL', 2000),
#  ('Vander Blue', 'LAL', 2000),
#  ('Vlade Divac', 'LAL', 2000),
#  ('Vladimir Radmanovic', 'LAL', 2000),
#  ('Von Wafer', 'LAL', 2000),
#  ('Wayne Ellington', 'LAL', 2000),
#  ('Wes Matthews', 'LAL', 2000),
#  ('Wesley Johnson', 'LAL', 2000),
#  ('Xavier Henry', 'LAL', 2000)]

# %% [markdown]
# **Let's find out the average age of players on the winning team in 1990**

# %%
# %%sql
# SELECT AVG(AGE),TeamName, Season.Year
# from Player JOIN Team ON (Player.TeamID=Team.TeamID)
#             JOIN SEASON ON (Player.SeasonID=Season.SeasonID);
# Out:
# Done.
# [(26.920931657983452, 'Warriors', 2016)]
